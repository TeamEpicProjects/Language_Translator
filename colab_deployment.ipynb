# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !pip install -q streamlit
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
#      |████████████████████████████████| 8.3 MB 5.2 MB/s
#      |████████████████████████████████| 111 kB 48.5 MB/s
#      |████████████████████████████████| 180 kB 49.4 MB/s
#      |████████████████████████████████| 76 kB 4.6 MB/s
#      |████████████████████████████████| 4.3 MB 37.4 MB/s
#      |████████████████████████████████| 63 kB 1.5 MB/s
#      |████████████████████████████████| 124 kB 58.5 MB/s
#      |████████████████████████████████| 788 kB 33.0 MB/s
#      |████████████████████████████████| 370 kB 71.8 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.20 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.4.1 which is incompatible.
# ...

# %%
# !pip install transformers
# !pip install sentencepiece
# Out:
# ...
#      |████████████████████████████████| 2.9 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 54.4 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 12.0 MB/s
# ...
#      |████████████████████████████████| 56 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 636 kB 52.5 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#      |████████████████████████████████| 1.2 MB 4.4 MB/s
# ...

# %%
# !gdown --id 1aYenxgsHeWkbodsWYBqJrGfu9uCEmcSR
# !gdown --id 15cnnZFHBGAJSVKJKInsYXCUQDDW4lPSE
# !gdown --id 1q1Ftc3Kra0rjmmoM9jCtHmqRezbeHcNy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1aYenxgsHeWkbodsWYBqJrGfu9uCEmcSR
# To: /content/eng_tokenizer.pkl
# 100% 67.1k/67.1k [00:00<00:00, 24.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=15cnnZFHBGAJSVKJKInsYXCUQDDW4lPSE
# To: /content/hi_tokenizer.pkl
# 100% 104k/104k [00:00<00:00, 37.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1q1Ftc3Kra0rjmmoM9jCtHmqRezbeHcNy
# To: /content/My_Translation_HI_EN_Model.h5
# 100% 23.4M/23.4M [00:00<00:00, 142MB/s]

# %%
get_ipython().system_raw('./ngrok http 8501 &')
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    'import sys, json; print(json.load(sys.stdin)["tunnels"])'
# Out:
# [{'name': 'command_line', 'uri': '/api/tunnels/command_line', 'public_url': 'https://98f9-35-237-136-151.ngrok.io', 'proto': 'https', 'config': {'addr': 'http://localhost:8501', 'inspect': True}, 'metrics': {'conns': {'count': 0, 'gauge': 0, 'rate1': 0, 'rate5': 0, 'rate15': 0, 'p50': 0, 'p90': 0, 'p95': 0, 'p99': 0}, 'http': {'count': 0, 'rate1': 0, 'rate5': 0, 'rate15': 0, 'p50': 0, 'p90': 0, 'p95': 0, 'p99': 0}}}, {'name': 'command_line (http)', 'uri': '/api/tunnels/command_line%20%28http%29', 'public_url': 'http://98f9-35-237-136-151.ngrok.io', 'proto': 'http', 'config': {'addr': 'http://localhost:8501', 'inspect': True}, 'metrics': {'conns': {'count': 0, 'gauge': 0, 'rate1': 0, 'rate5': 0, 'rate15': 0, 'p50': 0, 'p90': 0, 'p95': 0, 'p99': 0}, 'http': {'count': 0, 'rate1': 0, 'rate5': 0, 'rate15': 0, 'p50': 0, 'p90': 0, 'p95': 0, 'p99': 0}}}]

# %%
# !streamlit run packt_final.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://35.237.136.151:8501
#
# 2021-10-13 13:35:56.245518: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-10-13 13:35:56.245582: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (1a0b0764ba62): /proc/driver/nvidia/version does not exist
# 2021-10-13 13:35:59.118 Attempting to acquire lock 139995713825232 on /root/.cache/huggingface/transformers/e58016f2b38bd561fc034a57e9195ccbf8e43d15f5493de1eb0af739594b6d10.0c3cf9fbd5908f4566116c01bb37909dc5cf1d42363e166f996ee936ba7c6d72.lock
# 2021-10-13 13:35:59.119 Lock 139995713825232 acquired on /root/.cache/huggingface/transformers/e58016f2b38bd561fc034a57e9195ccbf8e43d15f5493de1eb0af739594b6d10.0c3cf9fbd5908f4566116c01bb37909dc5cf1d42363e166f996ee936ba7c6d72.lock
# ...
